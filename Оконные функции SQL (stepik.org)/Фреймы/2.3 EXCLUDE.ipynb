# %% [markdown]
# # EXCLUDE

# %% [markdown]
# ### 26 EXCLUDE 1

# %% [markdown]
# Есть таблица сотрудников `employees`:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В запросе задано окно:

# %%
WINDOW w AS (ORDER BY department, id
             ROWS BETWEEN 2 PRECEDING AND 2 FOLLOWING
             EXCLUDE CURRENT ROW)

# %% [markdown]
# Укажите идентификаторы записей, которые входят во фрейм, если текущая запись — Леонид.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 27 EXCLUDE 2

# %% [markdown]
# Есть таблица сотрудников `employees`:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В запросе задано окно:

# %%
WINDOW w AS (PARTITION BY department
             ORDER BY id
             ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW
             EXCLUDE CURRENT ROW)

# %% [markdown]
# Укажите идентификаторы записей, которые входят во фрейм, если текущая запись — Марина.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 28 EXCLUDE 3

# %% [markdown]
# Есть таблица сотрудников `employees`:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В запросе задано окно:

# %%
WINDOW w AS (ORDER BY salary
             RANGE BETWEEN 10 PRECEDING AND 10 FOLLOWING
             EXCLUDE GROUP)

# %% [markdown]
# Укажите идентификаторы записей, которые входят во фрейм, если текущая запись — Вероника.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 29 EXCLUDE 4

# %% [markdown]
# Есть таблица сотрудников `employees`:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В запросе задано окно:

# %%
WINDOW w AS (PARTITION BY city
             ORDER BY department
             GROUPS BETWEEN CURRENT ROW and UNBOUNDED FOLLOWING
             EXCLUDE TIES)

# %% [markdown]
# Укажите идентификаторы записей, которые входят во фрейм, если текущая запись —  Елена.

# %% [markdown]
# ### 30 EXCLUDE 5

# %% [markdown]
# Есть таблица сотрудников `employees`. Предположим, для каждого человека мы хотим посчитать среднюю зарплату сотрудников, которые получают столько же или больше, чем он — но не более чем +20 тыс. ₽ (p20_sal). При этом зарплату самого сотрудника учитывать не следует:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Напишите запрос, который это сделает.

# %% [markdown]
# Сортировка результата: salary, id

# %% [markdown]
# Пустая ячейка у Ивана — это null.

# %%
SELECT id, 
       name, 
       salary, ROUND(AVG(salary) OVER w) AS p20_sal
  FROM employees
WINDOW w AS (ORDER BY salary 
             RANGE BETWEEN CURRENT ROW AND 20 FOLLOWING EXCLUDE CURRENT ROW )
 ORDER BY salary, id
